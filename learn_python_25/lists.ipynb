# %% [markdown]
# <h1>List</h1>

# %%
# List is ordered collection of data 
runs = [20,15,99,100,75,200]

# %%
type(runs)
# Out:
# list

# %%
print(runs)
# Out:
# [20, 15, 99, 100, 75, 200]

# %%
# empty list
empty_list = []
empty_list
# Out:
# []

# %%
empty_list = list()
empty_list
# Out:
# []

# %%
#first match runs
runs[0] # indexing / position
# Out:
# 20

# %%
#4th match
runs[3]
# Out:
# 100
